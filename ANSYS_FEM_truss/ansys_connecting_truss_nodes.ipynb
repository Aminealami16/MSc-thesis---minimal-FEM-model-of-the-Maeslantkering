# %%
import numpy as np
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('..'))
import matplotlib.pyplot as plt
from scripts import nodes as n
from scripts import elements as e
from scripts import material_params as mat
from scipy.linalg import eigh
import plotly.graph_objects as go

# %%
n1 = n.nodes(0, 0, 0)
n2 = n.nodes(0, 0, 19)
n3 = n.nodes(15, 0, 0)
n4 = n.nodes(15, 0, 19)
n5 = n.nodes(30, 0, 0)
n6 = n.nodes(30, 0, 19)
n7 = n.nodes(45, 0, 0)
n8 = n.nodes(45, 0, 19)
n9 = n.nodes(60, 0, 0)
n10 = n.nodes(60, 0, 19)
n11 = n.nodes(0, 18, 9.5)
n12 = n.nodes(7.5, 18, 9.5)
n13 = n.nodes(22.5, 18, 9.5)
n14 = n.nodes(37.5, 18, 9.5)
n15 = n.nodes(52.5, 18, 9.5)
n16 = n.nodes(60, 18, 9.5)
nodes = [n1, n2, n3, n4, n5, n6, n7, 
         n8, n9, n10, n11, n12, n13, n14, n15, n16]

# %%
n.plot_nodes2d(nodes)

# %%
with open("connecting_nodes_truss.txt", "w") as f:
    for i, triple in enumerate(nodes, start=1):
        f.write(f"1 {i} {triple[0]} {triple[1]} {triple[2]}\n")
